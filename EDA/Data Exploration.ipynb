# %% [markdown]
# # Test Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
plt.style.use('ggplot')

# %%
test = pd.read_csv('test_10features.csv')
train_random = pd.read_csv('data160_10features.csv')
#train = pd.read_csv

# %%
for i in range(len(test.columns)-1):
    #summary = [round(np.percentile(test.loc[i].values, i), 1) for i in [1, 2, 5, 10, 25, 50]]
    #bins = list(range(int(summary[0]),int(summary[5]),((int(summary[5])-int(summary[0]))/26)))
    plt.hist(test.loc[i].values, 26, normed=True, alpha=0.7, histtype='stepfilled', color='steelblue',edgecolor='none')
    plt.hist(train.loc[i].values,26, normed=True, alpha=0.3,histtype='stepfilled', color='green',edgecolor='none') 
    plt.title('%s Distribution for Test and Train Data' % (test.columns[i]))
    plt.show()
    plt.clf()
# Out:
# /usr/local/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
train.pref_attachment.plot.hist(bins=12, alpha=0.5)

# %%
test.pref_attachment.plot.hist(bins=12, alpha=0.5)

# %%
train.common_friends.plot.hist(bins=12, alpha=0.5)

# %%
test.common_friends.plot.hist(bins=12, alpha=0.5)
